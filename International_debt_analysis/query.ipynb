# %%
# !pip install ipython-sql
# Out:
# ...
#   Obtaining dependency information for prettytable from https://files.pythonhosted.org/packages/4d/81/316b6a55a0d1f327d04cc7b0ba9d04058cb62de6c3a4d4b0df280cbe3b0b/prettytable-3.9.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for sqlalchemy>=2.0 from https://files.pythonhosted.org/packages/22/80/43ddb1ddeafdcbc3073c0e7a7d45b17678eeac4830c7e91bd6556527f311/SQLAlchemy-2.0.25-cp311-cp311-win_amd64.whl.metadata
# ...
#   Using cached sqlparse-0.4.4-py3-none-any.whl (41 kB)
# ...
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# ...
#   Obtaining dependency information for typing-extensions>=4.6.0 from https://files.pythonhosted.org/packages/b7/f4/6a90020cd2d93349b442bfcb657d0dc91eee65491600b2cb1d388bc98e6b/typing_extensions-4.9.0-py3-none-any.whl.metadata
# ...

# %%
import sqlite3
# %load_ext sql

# %%
conn = sqlite3.connect('database.db')  # Replace with your database path
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print(*tables, sep='\n')  # Print each table name on a new line

conn.close()
# Out:
# ('IDS_ALLCountries_Data',)

# %%
# %sql sqlite:///database.db

# %%
# %sql select * from IDS_ALLCountries_Data limit 10
# Out:
#  * sqlite:///database.db
# Done.
# [('Afghanistan', 'AFG', 'World', 'WLD', 'Average grace period on new external debt commitments (years)', 'DT.GPA.DPPG', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 10.25, 8.0833, 9.9575, 0.0, 7.8333, 0.0, 0.0, 0.0, 29.8333, 0.0, 0.0, 19.8356, 0.0, 17.9041, 0.0, 0.0, 0.0, None, None, None, None, None, None, None, None),
# ...

# %% [markdown]
# ## Finding the number of distinct countries
# <p>From the first ten rows, we can see the amount of debt owed by <em>Afghanistan</em> in the different debt indicators. But we do not know the number of different countries we have on the table. There are repetitions in the country names because a country is most likely to have debt in more than one debt indicator. </p>
# <p>Without a count of unique countries, we will not be able to perform our statistical analyses holistically. In this section, we are going to extract the number of unique countries present in the table. </p>

# %%
# %%sql
# SELECT count(distinct "country name") AS total_distinct_countries
# FROM IDS_ALLCountries_Data;
# Out:
#  * sqlite:///database.db
# Done.
# [(138,)]

# %% [markdown]
# ## Finding out the distinct debt indicators
# <p>We can see there are a total of 138 countries present on the table. As we saw in the first section, there is a column called <code>indicator_name</code> that briefly specifies the purpose of taking the debt. Just beside that column, there is another column called <code>indicator_code</code> which symbolizes the category of these debts. Knowing about these various debt indicators will help us to understand the areas in which a country can possibly be indebted to. </p>

# %%
# %%sql
# select distinct "series code" as distinct_debt_indicators from IDS_ALLCountries_Data
# order by distinct_debt_indicators;
# Out:
#  * sqlite:///database.db
# Done.
# [(None,),
#  ('BM.GSR.TOTL.CD',),
#  ('BN.CAB.XOKA.CD',),
#  ('BX.GRT.EXTA.CD.DT',),
#  ('BX.GRT.TECH.CD.DT',),
#  ('BX.GSR.TOTL.CD',),
#  ('BX.KLT.DINV.CD.DT',),
#  ('BX.KLT.DREM.CD.DT',),
#  ('BX.PEF.TOTL.CD.DT',),
#  ('BX.TRF.PWKR.CD.DT',),
#  ('DT.AMT.BLAT.CB.CD',),
#  ('DT.AMT.BLAT.CD',),
#  ('DT.AMT.BLAT.GG.CD',),
#  ('DT.AMT.BLAT.OPS.CD',),
#  ('DT.AMT.BLAT.PRVG.CD',),
#  ('DT.AMT.BLAT.PS.CD',),
#  ('DT.AMT.BLTC.CB.CD',),
#  ('DT.AMT.BLTC.CD',),
#  ('DT.AMT.BLTC.GG.CD',),
#  ('DT.AMT.BLTC.OPS.CD',),
#  ('DT.AMT.BLTC.PRVG.CD',),
#  ('DT.AMT.BLTC.PS.CD',),
#  ('DT.AMT.DECB.CD',),
#  ('DT.AMT.DEGG.CD',),
#  ('DT.AMT.DEPS.CD',),
#  ('DT.AMT.DIMF.CD',),
#  ('DT.AMT.DLTF.CD',),
#  ('DT.AMT.DLXF.CD',),
#  ('DT.AMT.DOPS.CD',),
#  ('DT.AMT.DPNG.CD',),
#  ('DT.AMT.DPPG.CD',),
#  ('DT.AMT.MIBR.CD',),
#  ('DT.AMT.MIDA.CD',),
#  ('DT.AMT.MLAT.CB.CD',),
#  ('DT.AMT.MLAT.CD',),
#  ('DT.AMT.MLAT.GG.CD',),
#  ('DT.AMT.MLAT.OPS.CD',),
# ...

# %%
# %%sql
# select count(distinct "series code") as count_distinct_codes from IDS_ALLCountries_Data;
# Out:
#  * sqlite:///database.db
# Done.
# [(572,)]

# %% [markdown]
# ## Totaling the amount of debt owed by the countries
# <p>As mentioned earlier, the financial debt of a particular country represents its economic state. But if we were to project this on an overall global scale, how we will approach it?</p>
# <p>Let's switch gears from the debt indicators now and find out the total amount of debt (in USD) that is owed by the different countries. This will give us a sense of how the overall economy of the entire world is holding up.</p>

# %%
# %%sql
# SELECT
#     "Country Name" as Country,
#     ROUND(
#         SUM(COALESCE(NULLIF("1970", ''), 0) +
#             COALESCE(NULLIF("1971", ''), 0) +
#             COALESCE(NULLIF("1972", ''), 0) +
#             COALESCE(NULLIF("1973", ''), 0) +
#             COALESCE(NULLIF("1974", ''), 0) +
#             COALESCE(NULLIF("1975", ''), 0) +
#             COALESCE(NULLIF("1976", ''), 0) +
#             COALESCE(NULLIF("1977", ''), 0) +
#             COALESCE(NULLIF("1978", ''), 0) +
#             COALESCE(NULLIF("1979", ''), 0) +
#             COALESCE(NULLIF("1980", ''), 0) +
#             COALESCE(NULLIF("1981", ''), 0) +
#             COALESCE(NULLIF("1982", ''), 0) +
#             COALESCE(NULLIF("1983", ''), 0) +
#             COALESCE(NULLIF("1984", ''), 0) +
#             COALESCE(NULLIF("1985", ''), 0) +
#             COALESCE(NULLIF("1986", ''), 0) +
#             COALESCE(NULLIF("1987", ''), 0) +
#             COALESCE(NULLIF("1988", ''), 0) +
#             COALESCE(NULLIF("1989", ''), 0) +
#             COALESCE(NULLIF("1990", ''), 0) +
#             COALESCE(NULLIF("1991", ''), 0) +
#             COALESCE(NULLIF("1992", ''), 0) +
#             COALESCE(NULLIF("1993", ''), 0) +
#             COALESCE(NULLIF("1994", ''), 0) +
#             COALESCE(NULLIF("1995", ''), 0) +
#             COALESCE(NULLIF("1996", ''), 0) +
#             COALESCE(NULLIF("1997", ''), 0) +
#             COALESCE(NULLIF("1998", ''), 0) +
#             COALESCE(NULLIF("1999", ''), 0) +
#             COALESCE(NULLIF("2000", ''), 0) +
#             COALESCE(NULLIF("2001", ''), 0) +
#             COALESCE(NULLIF("2002", ''), 0) +
#             COALESCE(NULLIF("2003", ''), 0) +
#             COALESCE(NULLIF("2004", ''), 0) +
#             COALESCE(NULLIF("2005", ''), 0) +
#             COALESCE(NULLIF("2006", ''), 0) +
#             COALESCE(NULLIF("2007", ''), 0) +
#             COALESCE(NULLIF("2008", ''), 0) +
#             COALESCE(NULLIF("2009", ''), 0) +
#             COALESCE(NULLIF("2010", ''), 0) +
#             COALESCE(NULLIF("2011", ''), 0) +
#             COALESCE(NULLIF("2012", ''), 0) +
#             COALESCE(NULLIF("2013", ''), 0) +
#             COALESCE(NULLIF("2014", ''), 0) +
#             COALESCE(NULLIF("2015", ''), 0) +
#             COALESCE(NULLIF("2016", ''), 0) +
#             COALESCE(NULLIF("2017", ''), 0) +
#             COALESCE(NULLIF("2018", ''), 0) +
#             COALESCE(NULLIF("2019", ''), 0) +
#             COALESCE(NULLIF("2020", ''), 0) +
#             COALESCE(NULLIF("2021", ''), 0) +
#             COALESCE(NULLIF("2022", ''), 0) +
#             COALESCE(NULLIF("2023", ''), 0) +
#             COALESCE(NULLIF("2024", ''), 0) +
#             COALESCE(NULLIF("2025", ''), 0) +
#             COALESCE(NULLIF("2026", ''), 0) +
#             COALESCE(NULLIF("2027", ''), 0) +
#             COALESCE(NULLIF("2028", ''), 0) +
#             COALESCE(NULLIF("2029", ''), 0) +
#             COALESCE(NULLIF("2030", ''), 0)
#         ) / 1000000, 2) AS total_debt
# FROM IDS_ALLCountries_Data
# GROUP BY "Country Name";
# Out:
#  * sqlite:///database.db
# Done.
# [(None, 0.0),
#  ('Afghanistan', 1095863.47),
#  ('Albania', 2640183.15),
#  ('Algeria', 23523169.56),
#  ('Angola', 21102407.67),
#  ('Argentina', 88752384.31),
#  ('Armenia', 2822122.11),
#  ('Azerbaijan', 5983513.09),
#  ('Bangladesh', 28346695.35),
#  ('Belarus', 10243905.91),
#  ('Belize', 684034.97),
#  ('Benin', 2240578.69),
#  ('Bhutan', 828748.95),
#  ('Bolivia', 6602878.83),
#  ('Bosnia and Herzegovina', 3848320.39),
#  ('Botswana', 1727211.02),
#  ('Brazil', 219416389.03),
#  ('Bulgaria', 14733053.65),
#  ('Burkina Faso', 2990661.07),
#  ('Burundi', 780041.59),
#  ('Cabo Verde', 687096.72),
#  ('Cambodia', 4418930.58),
#  ('Cameroon', 6838803.35),
#  ('Central African Republic', 595955.21),
#  ('Chad', 1624885.53),
#  ('China', 554296885.59),
#  ('Colombia', 47133857.78),
#  ('Comoros', 217161.65),
#  ('Congo, Dem. Rep.', 7030663.97),
#  ('Congo, Rep.', 4221310.86),
#  ('Costa Rica', 8297542.54),
#  ("Cote d'Ivoire", 11730027.34),
# ...

# %% [markdown]
# ## Country with the highest debt
# <p>"Human beings cannot comprehend very large or very small numbers. It would be useful for us to acknowledge that fact." - <a href="https://en.wikipedia.org/wiki/Daniel_Kahneman">Daniel Kahneman</a>. That is more than <em>3 million <strong>million</strong></em> USD, an amount which is really hard for us to fathom. </p>
# <p>Now that we have the exact total of the amounts of debt owed by several countries, let's now find out the country that owns the highest amount of debt along with the amount. <strong>Note</strong> that this debt is the sum of different debts owed by a country across several categories. This will help to understand more about the country in terms of its socio-economic scenarios. We can also find out the category in which the country owns its highest debt. But we will leave that for now. </p>

# %%
# %%sql
# WITH TotalDebtCTE AS (
#     SELECT
#         "Country Name" as Country,
#         ROUND(
#             SUM(
#                 COALESCE(NULLIF("1970", ''), 0) +
#                 COALESCE(NULLIF("1971", ''), 0) +
#                 COALESCE(NULLIF("1972", ''), 0) +
#                 COALESCE(NULLIF("1973", ''), 0) +
#                 COALESCE(NULLIF("1974", ''), 0) +
#                 COALESCE(NULLIF("1975", ''), 0) +
#                 COALESCE(NULLIF("1976", ''), 0) +
#                 COALESCE(NULLIF("1977", ''), 0) +
#                 COALESCE(NULLIF("1978", ''), 0) +
#                 COALESCE(NULLIF("1979", ''), 0) +
#                 COALESCE(NULLIF("1980", ''), 0) +
#                 COALESCE(NULLIF("1981", ''), 0) +
#                 COALESCE(NULLIF("1982", ''), 0) +
#                 COALESCE(NULLIF("1983", ''), 0) +
#                 COALESCE(NULLIF("1984", ''), 0) +
#                 COALESCE(NULLIF("1985", ''), 0) +
#                 COALESCE(NULLIF("1986", ''), 0) +
#                 COALESCE(NULLIF("1987", ''), 0) +
#                 COALESCE(NULLIF("1988", ''), 0) +
#                 COALESCE(NULLIF("1989", ''), 0) +
#                 COALESCE(NULLIF("1990", ''), 0) +
#                 COALESCE(NULLIF("1991", ''), 0) +
#                 COALESCE(NULLIF("1992", ''), 0) +
#                 COALESCE(NULLIF("1993", ''), 0) +
#                 COALESCE(NULLIF("1994", ''), 0) +
#                 COALESCE(NULLIF("1995", ''), 0) +
#                 COALESCE(NULLIF("1996", ''), 0) +
#                 COALESCE(NULLIF("1997", ''), 0) +
#                 COALESCE(NULLIF("1998", ''), 0) +
#                 COALESCE(NULLIF("1999", ''), 0) +
#                 COALESCE(NULLIF("2000", ''), 0) +
#                 COALESCE(NULLIF("2001", ''), 0) +
#                 COALESCE(NULLIF("2002", ''), 0) +
#                 COALESCE(NULLIF("2003", ''), 0) +
#                 COALESCE(NULLIF("2004", ''), 0) +
#                 COALESCE(NULLIF("2005", ''), 0) +
#                 COALESCE(NULLIF("2006", ''), 0) +
#                 COALESCE(NULLIF("2007", ''), 0) +
#                 COALESCE(NULLIF("2008", ''), 0) +
#                 COALESCE(NULLIF("2009", ''), 0) +
#                 COALESCE(NULLIF("2010", ''), 0) +
#                 COALESCE(NULLIF("2011", ''), 0) +
#                 COALESCE(NULLIF("2012", ''), 0) +
#                 COALESCE(NULLIF("2013", ''), 0) +
#                 COALESCE(NULLIF("2014", ''), 0) +
#                 COALESCE(NULLIF("2015", ''), 0) +
#                 COALESCE(NULLIF("2016", ''), 0) +
#                 COALESCE(NULLIF("2017", ''), 0) +
#                 COALESCE(NULLIF("2018", ''), 0) +
#                 COALESCE(NULLIF("2019", ''), 0) +
#                 COALESCE(NULLIF("2020", ''), 0) +
#                 COALESCE(NULLIF("2021", ''), 0) +
#                 COALESCE(NULLIF("2022", ''), 0) +
#                 COALESCE(NULLIF("2023", ''), 0) +
#                 COALESCE(NULLIF("2024", ''), 0) +
#                 COALESCE(NULLIF("2025", ''), 0) +
#                 COALESCE(NULLIF("2026", ''), 0) +
#                 COALESCE(NULLIF("2027", ''), 0) +
#                 COALESCE(NULLIF("2028", ''), 0) +
#                 COALESCE(NULLIF("2029", ''), 0) +
#                 COALESCE(NULLIF("2030", ''), 0)
#             ) / 1000000, 2) AS total_debt
#     FROM IDS_ALLCountries_Data
#     GROUP BY "Country Name"
# )
# SELECT
#     Country,
#     total_debt
# FROM TotalDebtCTE
# WHERE Country IS NOT NULL  -- Exclude rows where Country is NULL
# ORDER BY total_debt DESC
# LIMIT 10;
# Out:
#  * sqlite:///database.db
# Done.
# [('Low & middle income', 2753475872.83),
#  ('Middle income', 2665937529.78),
#  ('Upper middle income', 1909881949.88),
#  ('East Asia & Pacific (excluding high income)', 856720046.33),
#  ('Lower middle income', 757424121.33),
#  ('Latin America & Caribbean (excluding high income)', 679763996.0),
#  ('China', 554296885.59),
#  ('Europe & Central Asia (excluding high income)', 466221384.22),
#  ('IDA total', 343489942.56),
#  ('South Asia', 288359098.81)]

# %% [markdown]
# ## Average amount of debt across indicators
# <p>So, it was <em>China</em>. A more in-depth breakdown of China's debts can be found <a href="https://datatopics.worldbank.org/debt/ids/country/CHN">here</a>. </p>
# <p>We now have a brief overview of the dataset and a few of its summary statistics. We already have an idea of the different debt indicators in which the countries owe their debts. We can dig even further to find out on an average how much debt a country owes? This will give us a better sense of the distribution of the amount of debt across different indicators.</p>

# %%
# %%sql
# SELECT
#     "Series Code" AS debt_indicator,
#     "Series Name" AS indicator_name,
#     ROUND(AVG(
#         COALESCE(NULLIF("1970", ''), 0) +
#         COALESCE(NULLIF("1971", ''), 0) +
#         COALESCE(NULLIF("1972", ''), 0) +
#         COALESCE(NULLIF("1973", ''), 0) +
#         COALESCE(NULLIF("1974", ''), 0) +
#         COALESCE(NULLIF("1975", ''), 0) +
#         COALESCE(NULLIF("1976", ''), 0) +
#         COALESCE(NULLIF("1977", ''), 0) +
#         COALESCE(NULLIF("1978", ''), 0) +
#         COALESCE(NULLIF("1979", ''), 0) +
#         COALESCE(NULLIF("1980", ''), 0) +
#         COALESCE(NULLIF("1981", ''), 0) +
#         COALESCE(NULLIF("1982", ''), 0) +
#         COALESCE(NULLIF("1983", ''), 0) +
#         COALESCE(NULLIF("1984", ''), 0) +
#         COALESCE(NULLIF("1985", ''), 0) +
#         COALESCE(NULLIF("1986", ''), 0) +
#         COALESCE(NULLIF("1987", ''), 0) +
#         COALESCE(NULLIF("1988", ''), 0) +
#         COALESCE(NULLIF("1989", ''), 0) +
#         COALESCE(NULLIF("1990", ''), 0) +
#         COALESCE(NULLIF("1991", ''), 0) +
#         COALESCE(NULLIF("1992", ''), 0) +
#         COALESCE(NULLIF("1993", ''), 0) +
#         COALESCE(NULLIF("1994", ''), 0) +
#         COALESCE(NULLIF("1995", ''), 0) +
#         COALESCE(NULLIF("1996", ''), 0) +
#         COALESCE(NULLIF("1997", ''), 0) +
#         COALESCE(NULLIF("1998", ''), 0) +
#         COALESCE(NULLIF("1999", ''), 0) +
#         COALESCE(NULLIF("2000", ''), 0) +
#         COALESCE(NULLIF("2001", ''), 0) +
#         COALESCE(NULLIF("2002", ''), 0) +
#         COALESCE(NULLIF("2003", ''), 0) +
#         COALESCE(NULLIF("2004", ''), 0) +
#         COALESCE(NULLIF("2005", ''), 0) +
#         COALESCE(NULLIF("2006", ''), 0) +
#         COALESCE(NULLIF("2007", ''), 0) +
#         COALESCE(NULLIF("2008", ''), 0) +
#         COALESCE(NULLIF("2009", ''), 0) +
#         COALESCE(NULLIF("2010", ''), 0) +
#         COALESCE(NULLIF("2011", ''), 0) +
#         COALESCE(NULLIF("2012", ''), 0) +
#         COALESCE(NULLIF("2013", ''), 0) +
#         COALESCE(NULLIF("2014", ''), 0) +
#         COALESCE(NULLIF("2015", ''), 0) +
#         COALESCE(NULLIF("2016", ''), 0) +
#         COALESCE(NULLIF("2017", ''), 0) +
#         COALESCE(NULLIF("2018", ''), 0) +
#         COALESCE(NULLIF("2019", ''), 0) +
#         COALESCE(NULLIF("2020", ''), 0) +
#         COALESCE(NULLIF("2021", ''), 0) +
#         COALESCE(NULLIF("2022", ''), 0) +
#         COALESCE(NULLIF("2023", ''), 0) +
#         COALESCE(NULLIF("2024", ''), 0) +
#         COALESCE(NULLIF("2025", ''), 0) +
#         COALESCE(NULLIF("2026", ''), 0) +
#         COALESCE(NULLIF("2027", ''), 0) +
#         COALESCE(NULLIF("2028", ''), 0) +
#         COALESCE(NULLIF("2029", ''), 0) +
#         COALESCE(NULLIF("2030", ''), 0)
#     ) / COUNT(DISTINCT "Country Name"), 2) AS average_debt
# FROM IDS_ALLCountries_Data
# GROUP BY debt_indicator, indicator_name
# ORDER BY average_debt DESC
# LIMIT 10;
# Out:
#  * sqlite:///database.db
# Done.
# [('NY.GNP.MKTP.CD', 'GNI (current US$)', 151480228107.27),
#  ('DT.DOD.DECT.CD', 'External debt stocks, total (DOD, current US$)', 40585855445.79),
#  ('BM.GSR.TOTL.CD', 'Imports of goods, services and primary income (current US$)', 39358680855.24),
#  ('BX.GSR.TOTL.CD', 'Exports of goods, services and primary income (current US$)', 37014029046.62),
#  ('DT.DOD.DLXF.CD', 'External debt stocks, long-term (DOD, current US$)', 30232286479.4),
#  ('FI.RES.TOTL.CD', 'Total reserves (includes gold, current US$)', 29406274682.19),
#  ('DT.DOD.DPPG.CD', 'External debt stocks, public and publicly guaranteed (PPG) (DOD, current US$)', 18541669492.38),
#  ('DT.DOD.DEPS.CD', 'External debt stocks, public sector (PPG) (DOD, current US$)', 18467819130.12),
#  ('DT.DOD.PUBS.CD', 'External debt stocks, long-term public sector (DOD, current US$)', 18463883613.47),
#  ('DT.DOD.VTOT.CD', 'External debt stocks, variable rate (DOD, current US$)', 17509330142.15)]

# %% [markdown]
# ## The highest amount of principal repayments
# <p>We can see that the indicator <code>NY.GNP.MKTP.CD</code> tops the chart of average debt. This category includes repayment of long term debts. Countries take on long-term debt to acquire immediate capital. More information about this category can be found <a href="https://datacatalog.worldbank.org/principal-repayments-external-debt-long-term-amt-current-us-0">here</a>. </p>
# <p>An interesting observation in the above finding is that there is a huge difference in the amounts of the indicators after the second one. This indicates that the first two indicators might be the most severe categories in which the countries owe their debts.</p>
# <p>We can investigate this a bit more so as to find out which country owes the highest amount of debt in the category of long term debts (<code>NY.GNP.MKTP.CD</code>). Since not all the countries suffer from the same kind of economic disturbances, this finding will allow us to understand that particular country's economic condition a bit more specifically. </p>

# %%
# %%sql
# WITH TotalDebtCTE AS (
#     SELECT
#         "Country Name" as Country,
#         "Series Code",
#         ROUND(
#             SUM(
#                 COALESCE(NULLIF("1970", ''), 0) +
#                 COALESCE(NULLIF("1971", ''), 0) +
#                 COALESCE(NULLIF("1972", ''), 0) +
#                 COALESCE(NULLIF("1973", ''), 0) +
#                 COALESCE(NULLIF("1974", ''), 0) +
#                 COALESCE(NULLIF("1975", ''), 0) +
#                 COALESCE(NULLIF("1976", ''), 0) +
#                 COALESCE(NULLIF("1977", ''), 0) +
#                 COALESCE(NULLIF("1978", ''), 0) +
#                 COALESCE(NULLIF("1979", ''), 0) +
#                 COALESCE(NULLIF("1980", ''), 0) +
#                 COALESCE(NULLIF("1981", ''), 0) +
#                 COALESCE(NULLIF("1982", ''), 0) +
#                 COALESCE(NULLIF("1983", ''), 0) +
#                 COALESCE(NULLIF("1984", ''), 0) +
#                 COALESCE(NULLIF("1985", ''), 0) +
#                 COALESCE(NULLIF("1986", ''), 0) +
#                 COALESCE(NULLIF("1987", ''), 0) +
#                 COALESCE(NULLIF("1988", ''), 0) +
#                 COALESCE(NULLIF("1989", ''), 0) +
#                 COALESCE(NULLIF("1990", ''), 0) +
#                 COALESCE(NULLIF("1991", ''), 0) +
#                 COALESCE(NULLIF("1992", ''), 0) +
#                 COALESCE(NULLIF("1993", ''), 0) +
#                 COALESCE(NULLIF("1994", ''), 0) +
#                 COALESCE(NULLIF("1995", ''), 0) +
#                 COALESCE(NULLIF("1996", ''), 0) +
#                 COALESCE(NULLIF("1997", ''), 0) +
#                 COALESCE(NULLIF("1998", ''), 0) +
#                 COALESCE(NULLIF("1999", ''), 0) +
#                 COALESCE(NULLIF("2000", ''), 0) +
#                 COALESCE(NULLIF("2001", ''), 0) +
#                 COALESCE(NULLIF("2002", ''), 0) +
#                 COALESCE(NULLIF("2003", ''), 0) +
#                 COALESCE(NULLIF("2004", ''), 0) +
#                 COALESCE(NULLIF("2005", ''), 0) +
#                 COALESCE(NULLIF("2006", ''), 0) +
#                 COALESCE(NULLIF("2007", ''), 0) +
#                 COALESCE(NULLIF("2008", ''), 0) +
#                 COALESCE(NULLIF("2009", ''), 0) +
#                 COALESCE(NULLIF("2010", ''), 0) +
#                 COALESCE(NULLIF("2011", ''), 0) +
#                 COALESCE(NULLIF("2012", ''), 0) +
#                 COALESCE(NULLIF("2013", ''), 0) +
#                 COALESCE(NULLIF("2014", ''), 0) +
#                 COALESCE(NULLIF("2015", ''), 0) +
#                 COALESCE(NULLIF("2016", ''), 0) +
#                 COALESCE(NULLIF("2017", ''), 0) +
#                 COALESCE(NULLIF("2018", ''), 0) +
#                 COALESCE(NULLIF("2019", ''), 0) +
#                 COALESCE(NULLIF("2020", ''), 0) +
#                 COALESCE(NULLIF("2021", ''), 0) +
#                 COALESCE(NULLIF("2022", ''), 0) +
#                 COALESCE(NULLIF("2023", ''), 0) +
#                 COALESCE(NULLIF("2024", ''), 0) +
#                 COALESCE(NULLIF("2025", ''), 0) +
#                 COALESCE(NULLIF("2026", ''), 0) +
#                 COALESCE(NULLIF("2027", ''), 0) +
#                 COALESCE(NULLIF("2028", ''), 0) +
#                 COALESCE(NULLIF("2029", ''), 0) +
#                 COALESCE(NULLIF("2030", ''), 0)
#             ) / 1000000, 2) AS total_debt
#     FROM IDS_ALLCountries_Data
#     GROUP BY "Country Name", "Series Code"
# )
# SELECT
#     Country,
#     total_debt
# FROM TotalDebtCTE
# WHERE "Series Code" = "NY.GNP.MKTP.CD" -- Exclude rows where Country is NULL
# ORDER BY total_debt DESC
# LIMIT 5;
# Out:
#  * sqlite:///database.db
# Done.
# [('Low & middle income', 548332621.0),
#  ('Middle income', 537448671.0),
#  ('Upper middle income', 412609069.0),
#  ('East Asia & Pacific (excluding high income)', 232437109.0),
#  ('China', 191288827.24)]

# %% [markdown]
# ## The most common debt indicator
# <p>China has the highest amount of debt in the long-term debt (<code>NY.GNP.MKTP.CD</code>) category. This is verified by <a href="https://data.worldbank.org/indicator/DT.AMT.DLXF.CD?end=2018&most_recent_value_desc=true">The World Bank</a>. It is often a good idea to verify our analyses like this since it validates that our investigations are correct. </p>
# <p>We saw that long-term debt is the topmost category when it comes to the average amount of debt. But is it the most common indicator in which the countries owe their debt? Let's find that out. </p>

# %%
# %%sql
# select "Series Code" as indicator_code, count("Series Code") as indicator_count from IDS_ALLCountries_Data
# group by indicator_code
# order by indicator_count, indicator_code desc
# limit 10;
# Out:
#  * sqlite:///database.db
# Done.
# [(None, 0),
#  ('SP.POP.TOTL', 136),
#  ('NY.GNP.MKTP.CD', 136),
#  ('FI.RES.TOTL.MO', 136),
#  ('FI.RES.TOTL.DT.ZS', 136),
#  ('FI.RES.TOTL.CD', 136),
#  ('DT.UND.PRVT.CD', 136),
#  ('DT.UND.OFFT.CD', 136),
#  ('DT.UND.DPPG.CD', 136),
#  ('DT.TXR.DPPG.CD', 136)]
